# %%
a=12
b=23
c=34
sum=a+b+c
print(sum)
avg=sum/3
print(avg)
# Out:
# 69
# 23.0

# %%
print("ishu")
# Out:
# ishu

# %%
a = 10
print(type(a))

b = 1/89
print(type(b))

c="ishu"
print(type(c))

d=78j
print(type(d))

f=True
print(type(f))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'complex'>
# <class 'bool'>

# %%
a=10
b=23
sum=a+b
print(sum)
# Out:
# 33

# %%
a = 19
a=str(a)
print(type(a))

w=12.9
w=int(w)
print(type(w))
# Out:
# <class 'str'>
# <class 'int'>

# %%
age=int(input("enter your age"))
print(age)
# Out:
# 234

# %%
a=int(input("enter a number"))
print(a)
# Out:
# 3435

# %%
a=int(input("enter a number"))

if a>10:
  print("ishu")

else:
  print("mallick")
# Out:
# ishu

# %%
year = int(input("Enter a year:- "))

if(year % 100 == 0 and year % 400 == 0):
    print("leap year")

elif year % 100 == 0 and year % 4 == 0:
    print("leap year")


else:
    print("not a leap year")
# Out:
# not a leap year

# %%
temp = int(input("enter a temprature in celcious"))

if temp < 0:
    print("freezing cold")

elif 0 < temp <20:
    print("very cold")

elif 20 < temp < 40:
    print("cold")

else :
    print("very hot")
# Out:
# very cold

# %%
for i in range(1,21):
    print(i)
